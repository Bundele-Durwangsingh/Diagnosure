# %% [markdown]
# # Importing Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Data spliting

# %%
heart_data = pd.read_csv("D:\project\Integrated Health Prognosis using Deep Learning\Data\heart_disease_data.csv")
X = heart_data.drop(columns='target', axis=1)
Y = heart_data['target']
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, stratify=Y, random_state=2)

# %% [markdown]
# # Accuracy test

# %%
LR = LogisticRegression()
LR.fit(X_train, Y_train)
pred_lr = LR.predict(X_test)
print("Accuracy score for Logistics Regression")
print(LR.score(X_test,Y_test))
# Out:
# Accuracy score for Logistics Regression
# 0.819672131147541
# C:\Users\bunde\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
L = LinearRegression()
L.fit(X_train, Y_train)
pred_l = L.predict(X_test)
print("Accuracy score for Logistics Regression")
print(L.score(X_test,Y_test))
# Out:
# Accuracy score for Logistics Regression
# 0.4185908034444866

# %%
sv = SVC()
sv.fit(X_train, Y_train)
pred_sv = sv.predict(X_test)
print("Accuracy score for Logistics Regression")
print(sv.score(X_test,Y_test))
# Out:
# Accuracy score for Logistics Regression
# 0.6229508196721312

# %%
DT=DecisionTreeClassifier()
DT.fit(X_train, Y_train)
pred_dt = DT.predict(X_test)
print("Accuracy score for Decision Tree")
print(DT.score(X_test,Y_test))
# Out:
# Accuracy score for Decision Tree
# 0.7704918032786885

# %%
RF=RandomForestClassifier()
RF.fit(X_train, Y_train)
pred_rf = RF.predict(X_test)
print("Accuracy score for Random Forest")
print(RF.score(X_test,Y_test))
# Out:
# Accuracy score for Random Forest
# 0.7868852459016393

# %% [markdown]
# # Confusion matrix and Classification report

# %% [markdown]
# ### Confusion Matrix and Classification report for Logistics Regression

# %%
classification_report_str=classification_report(Y_test, pred_lr)
print("Confusion Matrix:")
print(confusion_matrix(Y_test, pred_lr))
print("\nClassification Report:")
print(classification_report_str)
report_data = classification_report(Y_test, pred_lr, target_names=["Class 0", "Class 1"], output_dict=True)
report_df = pd.DataFrame(report_data).transpose()
plt.figure(figsize=(8, 6))
sns.heatmap(report_df.iloc[:-1, :3], annot=True, cmap='Blues', cbar=False, fmt=".2f", annot_kws={"size": 16})
plt.title('Classification Report Heatmap (Precision, Recall, F1-Score)')
plt.show()
# Out:
# Confusion Matrix:
# [[23  5]
#  [ 6 27]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81        28
#            1       0.84      0.82      0.83        33
#
#     accuracy                           0.82        61
#    macro avg       0.82      0.82      0.82        61
# weighted avg       0.82      0.82      0.82        61

# %% [markdown]
# ### Confusion Matrix and Classification report for Decision tree

# %%
classification_report_str=classification_report(Y_test, pred_dt)
print("Confusion Matrix:")
print(confusion_matrix(Y_test, pred_dt))
print("\nClassification Report:")
print(classification_report_str)
report_data = classification_report(Y_test, pred_dt, target_names=["Class 0", "Class 1"], output_dict=True)
report_df = pd.DataFrame(report_data).transpose()
plt.figure(figsize=(8, 6))
sns.heatmap(report_df.iloc[:-1, :3], annot=True, cmap='Blues', cbar=False, fmt=".2f", annot_kws={"size": 16})
plt.title('Classification Report Heatmap (Precision, Recall, F1-Score)')
plt.show()
# Out:
# Confusion Matrix:
# [[21  7]
#  [ 7 26]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        28
#            1       0.79      0.79      0.79        33
#
#     accuracy                           0.77        61
#    macro avg       0.77      0.77      0.77        61
# weighted avg       0.77      0.77      0.77        61

# %% [markdown]
# ### Confusion Matrix and Classification report for Random forest

# %%
classification_report_str=classification_report(Y_test, pred_rf)
print("Confusion Matrix:")
print(confusion_matrix(Y_test, pred_rf))
print("\nClassification Report:")
print(classification_report_str)
report_data = classification_report(Y_test, pred_rf, target_names=["Class 0", "Class 1"], output_dict=True)
report_df = pd.DataFrame(report_data).transpose()
plt.figure(figsize=(8, 6))
sns.heatmap(report_df.iloc[:-1, :3], annot=True, cmap='Blues', cbar=False, fmt=".2f", annot_kws={"size": 16})
plt.title('Classification Report Heatmap (Precision, Recall, F1-Score)')
plt.show()
# Out:
# Confusion Matrix:
# [[22  6]
#  [ 7 26]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.77        28
#            1       0.81      0.79      0.80        33
#
#     accuracy                           0.79        61
#    macro avg       0.79      0.79      0.79        61
# weighted avg       0.79      0.79      0.79        61

# %% [markdown]
# # Comparison graph for model accuracy

# %%
model_name=['linear regression','SVM','Decission tres','Random forest','logistic regression']
model_acc=[L.score(X_test,Y_test),sv.score(X_test,Y_test),DT.score(X_test,Y_test),RF.score(X_test,Y_test),LR.score(X_test,Y_test)]
plt.bar(model_name, model_acc)
plt.title('Model Accuracy for heart disease ')
plt.xlabel('Model Name')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.show()
