# %%
import cv2
import os
import tensorflow as tf
from tensorflow import keras
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import normalize
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.utils import to_categorical

image_directory='D:/test code/test/Data/Brain tumor dataset/brain_tumor_dataset'

no_tumor_images=os.listdir(image_directory+ '/no')
yes_tumor_images=os.listdir(image_directory+ '/yes')
dataset=[]
label=[]

INPUT_SIZE=64
# print(no_tumor_images)

# path='no0.jpg'

# print(path.split('.')[1])

for i , image_name in enumerate(no_tumor_images):
    if(image_name.split('.')[1]=='jpg'):
        image=cv2.imread(image_directory+'/no/'+image_name)
        image=Image.fromarray(image,'RGB')
        image=image.resize((64,64))
        dataset.append(np.array(image))
        label.append(0)

for i , image_name in enumerate(yes_tumor_images):
    if(image_name.split('.')[1]=='jpg'):
        image=cv2.imread(image_directory+'/yes/'+image_name)
        image=Image.fromarray(image, 'RGB')
        image=image.resize((64,64))
        dataset.append(np.array(image))
        label.append(1)

dataset=np.array(dataset)
label=np.array(label)


x_train, x_test, y_train, y_test=train_test_split(dataset, label, test_size=0.2, random_state=0)

# Reshape = (n, image_width, image_height, n_channel)

# print(x_train.shape)
# print(y_train.shape)

# print(x_test.shape)
# print(y_test.shape)

x_train=normalize(x_train, axis=1)
x_test=normalize(x_test, axis=1)

y_train=to_categorical(y_train , num_classes=2)
y_test=to_categorical(y_test , num_classes=2)



# Model Building
# 64,64,3

model=Sequential()

model.add(Conv2D(32, (3,3), input_shape=(INPUT_SIZE, INPUT_SIZE, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32, (3,3), kernel_initializer='he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Conv2D(64, (3,3), kernel_initializer='he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('softmax'))


# Binary CrossEntropy= 1, sigmoid
# Categorical Cross Entryopy= 2 , softmax

model.compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])


model.fit(x_train, y_train, 
batch_size=16, 
verbose=1, epochs=10, 
validation_data=(x_test, y_test),
shuffle=False)
# Out:
# Epoch 1/10
# 9/9 [==============================] - 1s 55ms/step - loss: 0.6814 - accuracy: 0.5662 - val_loss: 0.6379 - val_accuracy: 0.4857
# Epoch 2/10
# 9/9 [==============================] - 0s 53ms/step - loss: 0.6370 - accuracy: 0.6250 - val_loss: 0.5740 - val_accuracy: 0.8000
# Epoch 3/10
# 9/9 [==============================] - 1s 58ms/step - loss: 0.5829 - accuracy: 0.7059 - val_loss: 0.4947 - val_accuracy: 0.8286
# Epoch 4/10
# 9/9 [==============================] - 0s 44ms/step - loss: 0.5589 - accuracy: 0.7353 - val_loss: 0.4778 - val_accuracy: 0.7714
# Epoch 5/10
# 9/9 [==============================] - 0s 46ms/step - loss: 0.5198 - accuracy: 0.7647 - val_loss: 0.4580 - val_accuracy: 0.8286
# Epoch 6/10
# 9/9 [==============================] - 0s 53ms/step - loss: 0.4546 - accuracy: 0.8162 - val_loss: 0.4155 - val_accuracy: 0.8286
# Epoch 7/10
# 9/9 [==============================] - 0s 42ms/step - loss: 0.4541 - accuracy: 0.8162 - val_loss: 0.4063 - val_accuracy: 0.8286
# Epoch 8/10
# 9/9 [==============================] - 0s 39ms/step - loss: 0.4378 - accuracy: 0.8603 - val_loss: 0.4106 - val_accuracy: 0.8571
# Epoch 9/10
# 9/9 [==============================] - 0s 43ms/step - loss: 0.4007 - accuracy: 0.8676 - val_loss: 0.3957 - val_accuracy: 0.8571
# Epoch 10/10
# 9/9 [==============================] - 0s 39ms/step - loss: 0.3665 - accuracy: 0.8456 - val_loss: 0.3690 - val_accuracy: 0.8571

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.utils import to_categorical

# Load your data and preprocess it as you did before

# Define the input size
INPUT_SIZE = 64

# Split your data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(dataset, label, test_size=0.2, random_state=0)

# Normalize your data
x_train = normalize(x_train, axis=1)
x_test = normalize(x_test, axis=1)

# Convert labels to categorical
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

# Create a new model
model = Sequential()

# Add a Flatten layer to convert input data to 1D
model.add(Flatten(input_shape=(INPUT_SIZE, INPUT_SIZE, 3)))

# You can add fully connected layers as needed
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Output layer with 2 classes
model.add(Dense(2))
model.add(Activation('softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, batch_size=16, verbose=1, epochs=10, validation_data=(x_test, y_test), shuffle=False)
# Out:
# Epoch 1/10
# 9/9 [==============================] - 1s 40ms/step - loss: 1.0665 - accuracy: 0.4926 - val_loss: 1.1126 - val_accuracy: 0.4857
# Epoch 2/10
# 9/9 [==============================] - 0s 27ms/step - loss: 1.0458 - accuracy: 0.5000 - val_loss: 0.6441 - val_accuracy: 0.5714
# Epoch 3/10
# 9/9 [==============================] - 0s 27ms/step - loss: 0.8157 - accuracy: 0.6103 - val_loss: 0.7216 - val_accuracy: 0.6000
# Epoch 4/10
# 9/9 [==============================] - 0s 33ms/step - loss: 0.8377 - accuracy: 0.5735 - val_loss: 0.6569 - val_accuracy: 0.5429
# Epoch 5/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6128 - accuracy: 0.6618 - val_loss: 0.6480 - val_accuracy: 0.6000
# Epoch 6/10
# 9/9 [==============================] - 0s 27ms/step - loss: 0.6052 - accuracy: 0.6912 - val_loss: 0.6487 - val_accuracy: 0.5714
# Epoch 7/10
# 9/9 [==============================] - 0s 26ms/step - loss: 0.6362 - accuracy: 0.6544 - val_loss: 0.6388 - val_accuracy: 0.6857
# Epoch 8/10
# 9/9 [==============================] - 0s 47ms/step - loss: 0.5872 - accuracy: 0.6985 - val_loss: 0.6248 - val_accuracy: 0.6571
# Epoch 9/10
# 9/9 [==============================] - 0s 51ms/step - loss: 0.5446 - accuracy: 0.7059 - val_loss: 0.6084 - val_accuracy: 0.6857
# Epoch 10/10
# 9/9 [==============================] - 0s 36ms/step - loss: 0.5965 - accuracy: 0.6544 - val_loss: 0.5996 - val_accuracy: 0.6857

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from keras.applications import VGG16
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.utils import to_categorical

# Load your data and preprocess it as you did before

# Define the input size
INPUT_SIZE = 64

# Split your data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(dataset, label, test_size=0.2, random_state=0)

# Normalize your data
x_train = normalize(x_train, axis=1)
x_test = normalize(x_test, axis=1)

# Convert labels to categorical
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

# Load the VGG16 model with pre-trained weights (include_top=False to exclude the final classification layer)
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(INPUT_SIZE, INPUT_SIZE, 3))

# Create a new model by adding your own classification layers on top of VGG16
model = Sequential()

# Add the VGG16 base model
model.add(base_model)

# Flatten the output of the VGG16 model
model.add(Flatten())

# You can add fully connected layers as needed
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Output layer with 2 classes
model.add(Dense(2))
model.add(Activation('softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, batch_size=16, verbose=1, epochs=10, validation_data=(x_test, y_test), shuffle=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 81s 1us/step
# Epoch 1/10
# 9/9 [==============================] - 10s 952ms/step - loss: 1.5657 - accuracy: 0.4853 - val_loss: 0.6958 - val_accuracy: 0.5143
# Epoch 2/10
# 9/9 [==============================] - 8s 932ms/step - loss: 0.7777 - accuracy: 0.4853 - val_loss: 0.6959 - val_accuracy: 0.4857
# Epoch 3/10
# 9/9 [==============================] - 9s 973ms/step - loss: 0.7331 - accuracy: 0.4485 - val_loss: 0.6939 - val_accuracy: 0.3429
# Epoch 4/10
# 9/9 [==============================] - 9s 950ms/step - loss: 0.7486 - accuracy: 0.4265 - val_loss: 0.6918 - val_accuracy: 0.5714
# Epoch 5/10
# 9/9 [==============================] - 9s 956ms/step - loss: 0.6975 - accuracy: 0.5147 - val_loss: 0.6927 - val_accuracy: 0.5143
# Epoch 6/10
# 9/9 [==============================] - 9s 961ms/step - loss: 0.6925 - accuracy: 0.5515 - val_loss: 0.6938 - val_accuracy: 0.5143
# Epoch 7/10
# 9/9 [==============================] - 9s 978ms/step - loss: 0.6910 - accuracy: 0.5588 - val_loss: 0.6938 - val_accuracy: 0.4857
# Epoch 8/10
# 9/9 [==============================] - 9s 947ms/step - loss: 0.6938 - accuracy: 0.5000 - val_loss: 0.6935 - val_accuracy: 0.4857
# Epoch 9/10
# 9/9 [==============================] - 9s 949ms/step - loss: 0.6940 - accuracy: 0.4632 - val_loss: 0.6937 - val_accuracy: 0.4857
# Epoch 10/10
# 9/9 [==============================] - 9s 944ms/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6937 - val_accuracy: 0.4857

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from keras.applications import Xception
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, GlobalAveragePooling2D
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.xception import preprocess_input

# Load your data and preprocess it as you did before

# Define the input size, you can use 71x71 or larger
INPUT_SIZE = 71

# Split your data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(dataset, label, test_size=0.2, random_state=0)

# Resize your input images to meet the minimum size requirements
x_train_resized = []
x_test_resized = []
for img in x_train:
    x_train_resized.append(cv2.resize(img, (INPUT_SIZE, INPUT_SIZE)))
for img in x_test:
    x_test_resized.append(cv2.resize(img, (INPUT_SIZE, INPUT_SIZE)))

x_train_resized = np.array(x_train_resized)
x_test_resized = np.array(x_test_resized)

# Normalize your data
x_train_resized = preprocess_input(x_train_resized)
x_test_resized = preprocess_input(x_test_resized)

# Convert labels to categorical
y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

# Load the Xception model with pre-trained weights (include_top=False to exclude the final classification layer)
base_model = Xception(weights='imagenet', include_top=False, input_shape=(INPUT_SIZE, INPUT_SIZE, 3))

# Create a new model by adding your own classification layers on top of Xception
model = Sequential()

# Add the Xception base model
model.add(base_model)

# Global Average Pooling 2D
model.add(GlobalAveragePooling2D())

# You can add fully connected layers as needed
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Output layer with 2 classes
model.add(Dense(2))
model.add(Activation('softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(x_train_resized, y_train, batch_size=16, verbose=1, epochs=10, validation_data=(x_test_resized, y_test), shuffle=False)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 90s 1us/step
# Epoch 1/10
# 9/9 [==============================] - 20s 1s/step - loss: 0.6840 - accuracy: 0.6029 - val_loss: 4.0366 - val_accuracy: 0.5143
# Epoch 2/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.4889 - accuracy: 0.8824 - val_loss: 12.1973 - val_accuracy: 0.5143
# Epoch 3/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.4879 - accuracy: 0.8088 - val_loss: 15.1145 - val_accuracy: 0.5143
# Epoch 4/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.4032 - accuracy: 0.8750 - val_loss: 26.5969 - val_accuracy: 0.5143
# Epoch 5/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.3246 - accuracy: 0.9044 - val_loss: 19.2640 - val_accuracy: 0.5143
# Epoch 6/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.2325 - accuracy: 0.9412 - val_loss: 25.7479 - val_accuracy: 0.5429
# Epoch 7/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.1380 - accuracy: 0.9338 - val_loss: 19.1911 - val_accuracy: 0.6286
# Epoch 8/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.0872 - accuracy: 0.9412 - val_loss: 15.2351 - val_accuracy: 0.6000
# Epoch 9/10
# 9/9 [==============================] - 10s 1s/step - loss: 0.1045 - accuracy: 0.9559 - val_loss: 22.6284 - val_accuracy: 0.5429
# Epoch 10/10
# 9/9 [==============================] - 11s 1s/step - loss: 0.1379 - accuracy: 0.9485 - val_loss: 5.7669 - val_accuracy: 0.8857

# %%
import matplotlib.pyplot as plt

# Create a dictionary to store the accuracy scores for each model
model_accuracies = {
    'CNN': 85,# Replace with the actual accuracy for your CNN model
    'VGGNet': 84,  # Replace with the actual accuracy for your VGGNet model
    'Xception':80, # Replace with the actual accuracy for your Xception model
    'Feed forward ':71
}

# Extract model names and accuracy scores
model_names = list(model_accuracies.keys())
accuracies = list(model_accuracies.values())

# Create a bar graph
plt.figure(figsize=(8, 6))
plt.bar(model_names, accuracies, color='blue')
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy of Brain tumpur detection')
plt.ylim(0, 100)  # Set the y-axis limits to represent accuracy as a percentage (0 to 100%)
plt.show()

# %%
import cv2
import os
import tensorflow as tf
from tensorflow import keras
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import normalize, to_categorical
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

image_directory = 'D:\project\Personal\Major project src\Integrated-Health-Prognosis-using-Deep-Learning\Data\Brain tumor dataset'

no_tumor_images = os.listdir(image_directory + '/no')
yes_tumor_images = os.listdir(image_directory + '/yes')
dataset = []
label = []

INPUT_SIZE = 64

for i, image_name in enumerate(no_tumor_images):
    if image_name.split('.')[1] == 'jpg':
        image = cv2.imread(image_directory + '/no/' + image_name)
        image = Image.fromarray(image, 'RGB')
        image = image.resize((64, 64))
        dataset.append(np.array(image))
        label.append(0)

for i, image_name in enumerate(yes_tumor_images):
    if image_name.split('.')[1] == 'jpg':
        image = cv2.imread(image_directory + '/yes/' + image_name)
        image = Image.fromarray(image, 'RGB')
        image = image.resize((64, 64))
        dataset.append(np.array(image))
        label.append(1)

dataset = np.array(dataset)
label = np.array(label)

x_train, x_test, y_train, y_test = train_test_split(dataset, label, test_size=0.2, random_state=0)

x_train = normalize(x_train, axis=1)
x_test = normalize(x_test, axis=1)

y_train = to_categorical(y_train, num_classes=2)
y_test = to_categorical(y_test, num_classes=2)

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(INPUT_SIZE, INPUT_SIZE, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), kernel_initializer='he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), kernel_initializer='he_uniform'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(2))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=16, verbose=1, epochs=150, validation_data=(x_test, y_test), shuffle=False)

# Make predictions
predictions = model.predict(x_test)
pred_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Calculate confusion matrix and classification report
conf_matrix = confusion_matrix(true_labels, pred_labels)
classification_report_str = classification_report(true_labels, pred_labels, target_names=["Class 0", "Class 1"])

# Print confusion matrix and classification report
print("Confusion Matrix:")
print(conf_matrix)
print("\nClassification Report:")
print(classification_report_str)

# Plot heatmap of classification report
report_data = classification_report(true_labels, pred_labels, target_names=["Class 0", "Class 1"], output_dict=True)
report_df = pd.DataFrame(report_data).transpose()
plt.figure(figsize=(8, 6))
sns.heatmap(report_df.iloc[:-1, :3], annot=True, cmap='Blues', cbar=False, fmt=".2f", annot_kws={"size": 16})
plt.title('Classification Report Heatmap (Precision, Recall, F1-Score)')
plt.show()
# Out:
# Epoch 1/150
# 9/9 [==============================] - 1s 60ms/step - loss: 0.6892 - accuracy: 0.5441 - val_loss: 0.6540 - val_accuracy: 0.4857
# Epoch 2/150
# 9/9 [==============================] - 0s 42ms/step - loss: 0.6525 - accuracy: 0.6544 - val_loss: 0.6086 - val_accuracy: 0.6857
# Epoch 3/150
# 9/9 [==============================] - 0s 40ms/step - loss: 0.6316 - accuracy: 0.6324 - val_loss: 0.5569 - val_accuracy: 0.7714
# Epoch 4/150
# 9/9 [==============================] - 0s 43ms/step - loss: 0.5946 - accuracy: 0.6985 - val_loss: 0.5054 - val_accuracy: 0.8286
# Epoch 5/150
# 9/9 [==============================] - 0s 45ms/step - loss: 0.5277 - accuracy: 0.7500 - val_loss: 0.4654 - val_accuracy: 0.8286
# Epoch 6/150
# 9/9 [==============================] - 0s 42ms/step - loss: 0.5115 - accuracy: 0.7794 - val_loss: 0.4581 - val_accuracy: 0.8286
# Epoch 7/150
# 9/9 [==============================] - 0s 44ms/step - loss: 0.4702 - accuracy: 0.7941 - val_loss: 0.4467 - val_accuracy: 0.8571
# Epoch 8/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.4264 - accuracy: 0.8162 - val_loss: 0.4340 - val_accuracy: 0.8571
# Epoch 9/150
# 9/9 [==============================] - 0s 43ms/step - loss: 0.3976 - accuracy: 0.8676 - val_loss: 0.4126 - val_accuracy: 0.8286
# Epoch 10/150
# 9/9 [==============================] - 0s 47ms/step - loss: 0.3620 - accuracy: 0.8529 - val_loss: 0.4107 - val_accuracy: 0.8571
# Epoch 11/150
# 9/9 [==============================] - 0s 45ms/step - loss: 0.3380 - accuracy: 0.8676 - val_loss: 0.4113 - val_accuracy: 0.8286
# Epoch 12/150
# 9/9 [==============================] - 0s 45ms/step - loss: 0.2922 - accuracy: 0.8971 - val_loss: 0.4547 - val_accuracy: 0.7714
# Epoch 13/150
# 9/9 [==============================] - 0s 49ms/step - loss: 0.2651 - accuracy: 0.9044 - val_loss: 0.4302 - val_accuracy: 0.7714
# Epoch 14/150
# 9/9 [==============================] - 0s 43ms/step - loss: 0.2611 - accuracy: 0.9044 - val_loss: 0.4306 - val_accuracy: 0.8286
# Epoch 15/150
# 9/9 [==============================] - 0s 42ms/step - loss: 0.2166 - accuracy: 0.9338 - val_loss: 0.4114 - val_accuracy: 0.8000
# Epoch 16/150
# 9/9 [==============================] - 0s 49ms/step - loss: 0.1605 - accuracy: 0.9338 - val_loss: 0.4052 - val_accuracy: 0.8000
# Epoch 17/150
# 9/9 [==============================] - 0s 43ms/step - loss: 0.1282 - accuracy: 0.9706 - val_loss: 0.4549 - val_accuracy: 0.9143
# Epoch 18/150
# 9/9 [==============================] - 0s 49ms/step - loss: 0.1474 - accuracy: 0.9265 - val_loss: 0.4596 - val_accuracy: 0.8857
# Epoch 19/150
# 9/9 [==============================] - 0s 47ms/step - loss: 0.1186 - accuracy: 0.9706 - val_loss: 0.4774 - val_accuracy: 0.8000
# Epoch 20/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.1220 - accuracy: 0.9779 - val_loss: 0.4832 - val_accuracy: 0.9143
# Epoch 21/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0691 - accuracy: 0.9853 - val_loss: 0.4712 - val_accuracy: 0.8000
# Epoch 22/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0642 - accuracy: 0.9853 - val_loss: 0.4974 - val_accuracy: 0.8286
# Epoch 23/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0515 - accuracy: 0.9926 - val_loss: 0.5118 - val_accuracy: 0.8286
# Epoch 24/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.5615 - val_accuracy: 0.8000
# Epoch 25/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0536 - accuracy: 0.9853 - val_loss: 0.6131 - val_accuracy: 0.8857
# Epoch 26/150
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0439 - accuracy: 0.9853 - val_loss: 0.6042 - val_accuracy: 0.8571
# Epoch 27/150
# 9/9 [==============================] - 1s 59ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.6350 - val_accuracy: 0.8000
# Epoch 28/150
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.6454 - val_accuracy: 0.8286
# Epoch 29/150
# 9/9 [==============================] - 1s 61ms/step - loss: 0.0128 - accuracy: 1.0000 - val_loss: 0.6197 - val_accuracy: 0.8000
# Epoch 30/150
# 9/9 [==============================] - 1s 55ms/step - loss: 0.0190 - accuracy: 0.9926 - val_loss: 0.6222 - val_accuracy: 0.8000
# Epoch 31/150
# 9/9 [==============================] - 1s 76ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.6696 - val_accuracy: 0.8857
# Epoch 32/150
# 9/9 [==============================] - 1s 70ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.6816 - val_accuracy: 0.8857
# Epoch 33/150
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.7094 - val_accuracy: 0.8286
# Epoch 34/150
# 9/9 [==============================] - 0s 40ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.7507 - val_accuracy: 0.8286
# Epoch 35/150
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.7735 - val_accuracy: 0.8286
# Epoch 36/150
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.7669 - val_accuracy: 0.8000
# Epoch 37/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.8068 - val_accuracy: 0.8286
# Epoch 38/150
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.7754 - val_accuracy: 0.8000
# Epoch 39/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.7913 - val_accuracy: 0.9143
# Epoch 40/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.7394 - val_accuracy: 0.8286
# Epoch 41/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.8057 - val_accuracy: 0.8000
# Epoch 42/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.8557 - val_accuracy: 0.8000
# Epoch 43/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.8851 - val_accuracy: 0.8000
# Epoch 44/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.9012 - val_accuracy: 0.8571
# Epoch 45/150
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.8024 - val_accuracy: 0.8000
# Epoch 46/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.8059 - val_accuracy: 0.8000
# Epoch 47/150
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.8792 - val_accuracy: 0.8857
# Epoch 48/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.9032 - val_accuracy: 0.8571
# Epoch 49/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9080 - val_accuracy: 0.8000
# Epoch 50/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.9212 - val_accuracy: 0.8000
# Epoch 51/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.9693 - val_accuracy: 0.8857
# Epoch 52/150
# 9/9 [==============================] - 0s 52ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.9557 - val_accuracy: 0.8000
# Epoch 53/150
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.9849 - val_accuracy: 0.8000
# Epoch 54/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.0164 - val_accuracy: 0.8000
# Epoch 55/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.0335 - val_accuracy: 0.8000
# Epoch 56/150
# 9/9 [==============================] - 0s 33ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.0498 - val_accuracy: 0.8857
# Epoch 57/150
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.0637 - val_accuracy: 0.8857
# Epoch 58/150
# 9/9 [==============================] - 0s 40ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0713 - val_accuracy: 0.8286
# Epoch 59/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0665 - val_accuracy: 0.8000
# Epoch 60/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0647 - val_accuracy: 0.8000
# Epoch 61/150
# 9/9 [==============================] - 0s 37ms/step - loss: 9.1984e-04 - accuracy: 1.0000 - val_loss: 1.0722 - val_accuracy: 0.8000
# Epoch 62/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0815 - val_accuracy: 0.8000
# Epoch 63/150
# 9/9 [==============================] - 0s 37ms/step - loss: 5.3896e-04 - accuracy: 1.0000 - val_loss: 1.0918 - val_accuracy: 0.8000
# Epoch 64/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.1228 - val_accuracy: 0.8000
# Epoch 65/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.1186 - val_accuracy: 0.9143
# Epoch 66/150
# 9/9 [==============================] - 0s 35ms/step - loss: 9.9016e-04 - accuracy: 1.0000 - val_loss: 1.1598 - val_accuracy: 0.9143
# Epoch 67/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.1240 - val_accuracy: 0.8571
# Epoch 68/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.1449 - val_accuracy: 0.8000
# Epoch 69/150
# 9/9 [==============================] - 0s 35ms/step - loss: 9.0304e-04 - accuracy: 1.0000 - val_loss: 1.1780 - val_accuracy: 0.8000
# Epoch 70/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.1806 - val_accuracy: 0.8000
# Epoch 71/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.1474 - val_accuracy: 0.8000
# Epoch 72/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.1028 - val_accuracy: 0.8000
# Epoch 73/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0995 - val_accuracy: 0.8000
# Epoch 74/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1128 - val_accuracy: 0.8000
# Epoch 75/150
# 9/9 [==============================] - 0s 37ms/step - loss: 8.7167e-04 - accuracy: 1.0000 - val_loss: 1.1305 - val_accuracy: 0.8000
# Epoch 76/150
# 9/9 [==============================] - 0s 35ms/step - loss: 4.8427e-04 - accuracy: 1.0000 - val_loss: 1.1468 - val_accuracy: 0.8000
# Epoch 77/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1606 - val_accuracy: 0.8000
# Epoch 78/150
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.1936 - val_accuracy: 0.8857
# Epoch 79/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.0845 - val_accuracy: 0.8571
# Epoch 80/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.0405 - val_accuracy: 0.8000
# Epoch 81/150
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.0334 - val_accuracy: 0.8000
# Epoch 82/150
# 9/9 [==============================] - 0s 39ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.0939 - val_accuracy: 0.8857
# Epoch 83/150
# 9/9 [==============================] - 0s 35ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1150 - val_accuracy: 0.8857
# Epoch 84/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0173 - accuracy: 0.9926 - val_loss: 0.9815 - val_accuracy: 0.8000
# Epoch 85/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.7250 - val_accuracy: 0.8000
# Epoch 86/150
# 9/9 [==============================] - 0s 37ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9011 - val_accuracy: 0.9143
# Epoch 87/150
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.9649 - val_accuracy: 0.8571
# Epoch 88/150
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.0069 - val_accuracy: 0.8571
# Epoch 89/150
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.0351 - val_accuracy: 0.8571
# Epoch 90/150
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.0349 - val_accuracy: 0.8571
# Epoch 91/150
# 9/9 [==============================] - 0s 49ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.0021 - val_accuracy: 0.8000
# Epoch 92/150
# 9/9 [==============================] - 0s 51ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.9690 - val_accuracy: 0.8000
# Epoch 93/150
# 9/9 [==============================] - 0s 45ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.8747 - val_accuracy: 0.8286
# Epoch 94/150
# 9/9 [==============================] - 0s 57ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.9772 - val_accuracy: 0.8857
# Epoch 95/150
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 1.0467 - val_accuracy: 0.8286
# Epoch 96/150
# 9/9 [==============================] - 0s 50ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.1026 - val_accuracy: 0.8286
# Epoch 97/150
# 9/9 [==============================] - 1s 58ms/step - loss: 2.4946e-04 - accuracy: 1.0000 - val_loss: 1.1313 - val_accuracy: 0.8286
# Epoch 98/150
# 9/9 [==============================] - 0s 53ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.1720 - val_accuracy: 0.8286
# Epoch 99/150
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.2315 - val_accuracy: 0.8571
# Epoch 100/150
# 9/9 [==============================] - 0s 55ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.1986 - val_accuracy: 0.8000
# Epoch 101/150
# 9/9 [==============================] - 1s 65ms/step - loss: 0.0102 - accuracy: 0.9926 - val_loss: 1.1046 - val_accuracy: 0.9143
# Epoch 102/150
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.8926 - val_accuracy: 0.8000
# Epoch 103/150
# 9/9 [==============================] - 1s 58ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.9410 - val_accuracy: 0.8571
# Epoch 104/150
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.0021 - val_accuracy: 0.8571
# Epoch 105/150
# 9/9 [==============================] - 0s 49ms/step - loss: 9.0207e-04 - accuracy: 1.0000 - val_loss: 1.0771 - val_accuracy: 0.8000
# Epoch 106/150
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1088 - val_accuracy: 0.8286
# Epoch 107/150
# 9/9 [==============================] - 1s 56ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 1.1885 - val_accuracy: 0.8857
# Epoch 108/150
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.1940 - val_accuracy: 0.8857
# Epoch 109/150
# 9/9 [==============================] - 0s 44ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.1417 - val_accuracy: 0.8286
# Epoch 110/150
# 9/9 [==============================] - 0s 43ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.1611 - val_accuracy: 0.8000
# Epoch 111/150
# 9/9 [==============================] - 0s 42ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.2190 - val_accuracy: 0.8000
# Epoch 112/150
# 9/9 [==============================] - 0s 50ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.2758 - val_accuracy: 0.8000
# Epoch 113/150
# 9/9 [==============================] - 0s 53ms/step - loss: 2.3707e-04 - accuracy: 1.0000 - val_loss: 1.3106 - val_accuracy: 0.8000
# Epoch 114/150
# 9/9 [==============================] - 0s 50ms/step - loss: 3.5368e-04 - accuracy: 1.0000 - val_loss: 1.3314 - val_accuracy: 0.8000
# Epoch 115/150
# 9/9 [==============================] - 1s 57ms/step - loss: 3.7348e-04 - accuracy: 1.0000 - val_loss: 1.3499 - val_accuracy: 0.8286
# Epoch 116/150
# 9/9 [==============================] - 0s 41ms/step - loss: 1.8003e-04 - accuracy: 1.0000 - val_loss: 1.3608 - val_accuracy: 0.8286
# Epoch 117/150
# 9/9 [==============================] - 0s 48ms/step - loss: 2.8764e-04 - accuracy: 1.0000 - val_loss: 1.3550 - val_accuracy: 0.8000
# Epoch 118/150
# 9/9 [==============================] - 0s 56ms/step - loss: 8.7877e-05 - accuracy: 1.0000 - val_loss: 1.3542 - val_accuracy: 0.8000
# Epoch 119/150
# 9/9 [==============================] - 0s 41ms/step - loss: 6.1647e-04 - accuracy: 1.0000 - val_loss: 1.3753 - val_accuracy: 0.8857
# Epoch 120/150
# 9/9 [==============================] - 0s 55ms/step - loss: 7.6466e-05 - accuracy: 1.0000 - val_loss: 1.3977 - val_accuracy: 0.8857
# Epoch 121/150
# 9/9 [==============================] - 0s 41ms/step - loss: 1.1728e-04 - accuracy: 1.0000 - val_loss: 1.4101 - val_accuracy: 0.8857
# Epoch 122/150
# 9/9 [==============================] - 1s 60ms/step - loss: 1.3378e-04 - accuracy: 1.0000 - val_loss: 1.4227 - val_accuracy: 0.8857
# Epoch 123/150
# 9/9 [==============================] - 0s 41ms/step - loss: 2.3124e-04 - accuracy: 1.0000 - val_loss: 1.4179 - val_accuracy: 0.8857
# Epoch 124/150
# 9/9 [==============================] - 0s 41ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 1.3259 - val_accuracy: 0.8286
# Epoch 125/150
# 9/9 [==============================] - 0s 58ms/step - loss: 5.8042e-04 - accuracy: 1.0000 - val_loss: 1.2774 - val_accuracy: 0.8000
# Epoch 126/150
# 9/9 [==============================] - 0s 40ms/step - loss: 2.3145e-04 - accuracy: 1.0000 - val_loss: 1.2701 - val_accuracy: 0.8000
# Epoch 127/150
# 9/9 [==============================] - 0s 40ms/step - loss: 1.9207e-04 - accuracy: 1.0000 - val_loss: 1.2767 - val_accuracy: 0.8000
# Epoch 128/150
# 9/9 [==============================] - 0s 41ms/step - loss: 9.9329e-04 - accuracy: 1.0000 - val_loss: 1.3205 - val_accuracy: 0.8571
# Epoch 129/150
# 9/9 [==============================] - 0s 41ms/step - loss: 1.7026e-04 - accuracy: 1.0000 - val_loss: 1.3731 - val_accuracy: 0.8857
# Epoch 130/150
# 9/9 [==============================] - 0s 42ms/step - loss: 8.1600e-04 - accuracy: 1.0000 - val_loss: 1.3915 - val_accuracy: 0.8857
# Epoch 131/150
# 9/9 [==============================] - 0s 42ms/step - loss: 3.5872e-04 - accuracy: 1.0000 - val_loss: 1.3931 - val_accuracy: 0.8571
# Epoch 132/150
# 9/9 [==============================] - 0s 39ms/step - loss: 9.8319e-05 - accuracy: 1.0000 - val_loss: 1.3977 - val_accuracy: 0.8571
# Epoch 133/150
# 9/9 [==============================] - 0s 37ms/step - loss: 6.2169e-05 - accuracy: 1.0000 - val_loss: 1.4047 - val_accuracy: 0.8286
# Epoch 134/150
# 9/9 [==============================] - 1s 57ms/step - loss: 1.4482e-04 - accuracy: 1.0000 - val_loss: 1.4153 - val_accuracy: 0.8286
# Epoch 135/150
# 9/9 [==============================] - 1s 58ms/step - loss: 2.0158e-04 - accuracy: 1.0000 - val_loss: 1.4284 - val_accuracy: 0.8286
# Epoch 136/150
# 9/9 [==============================] - 0s 51ms/step - loss: 3.0503e-04 - accuracy: 1.0000 - val_loss: 1.4558 - val_accuracy: 0.8571
# Epoch 137/150
# 9/9 [==============================] - 0s 42ms/step - loss: 2.6818e-05 - accuracy: 1.0000 - val_loss: 1.4749 - val_accuracy: 0.8571
# Epoch 138/150
# 9/9 [==============================] - 1s 56ms/step - loss: 3.5685e-04 - accuracy: 1.0000 - val_loss: 1.4902 - val_accuracy: 0.8571
# Epoch 139/150
# 9/9 [==============================] - 1s 55ms/step - loss: 2.0700e-04 - accuracy: 1.0000 - val_loss: 1.4862 - val_accuracy: 0.8571
# Epoch 140/150
# 9/9 [==============================] - 0s 39ms/step - loss: 9.3686e-05 - accuracy: 1.0000 - val_loss: 1.4824 - val_accuracy: 0.8571
# Epoch 141/150
# 9/9 [==============================] - 0s 40ms/step - loss: 1.3079e-04 - accuracy: 1.0000 - val_loss: 1.4838 - val_accuracy: 0.8571
# Epoch 142/150
# 9/9 [==============================] - 1s 62ms/step - loss: 4.6558e-05 - accuracy: 1.0000 - val_loss: 1.4815 - val_accuracy: 0.8571
# Epoch 143/150
# 9/9 [==============================] - 0s 55ms/step - loss: 1.8916e-04 - accuracy: 1.0000 - val_loss: 1.4926 - val_accuracy: 0.8571
# Epoch 144/150
# 9/9 [==============================] - 0s 54ms/step - loss: 1.0726e-04 - accuracy: 1.0000 - val_loss: 1.5042 - val_accuracy: 0.8571
# Epoch 145/150
# 9/9 [==============================] - 0s 52ms/step - loss: 8.0828e-05 - accuracy: 1.0000 - val_loss: 1.5103 - val_accuracy: 0.8571
# Epoch 146/150
# 9/9 [==============================] - 0s 49ms/step - loss: 2.7392e-04 - accuracy: 1.0000 - val_loss: 1.5114 - val_accuracy: 0.8286
# Epoch 147/150
# 9/9 [==============================] - 0s 47ms/step - loss: 1.7951e-04 - accuracy: 1.0000 - val_loss: 1.5140 - val_accuracy: 0.8286
# Epoch 148/150
# 9/9 [==============================] - 1s 62ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.4889 - val_accuracy: 0.8000
# Epoch 149/150
# 9/9 [==============================] - 0s 47ms/step - loss: 1.9764e-04 - accuracy: 1.0000 - val_loss: 1.4381 - val_accuracy: 0.8000
# Epoch 150/150
# 9/9 [==============================] - 0s 47ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.5000 - val_accuracy: 0.9143
# 2/2 [==============================] - 0s 9ms/step
# Confusion Matrix:
# [[14  3]
#  [ 0 18]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       1.00      0.82      0.90        17
#      Class 1       0.86      1.00      0.92        18
#
#     accuracy                           0.91        35
#    macro avg       0.93      0.91      0.91        35
# weighted avg       0.93      0.91      0.91        35
